# %%
import pandas as pd
import numpy as np
import random
from sklearn.model_selection import train_test_split
from PIL import Image
import matplotlib.pyplot as plt
from torchvision import transforms, utils
import os

# %%
# check the image dataset
img_dir = "data/liver_MRI/"
count = 0
for file in os.listdir(img_dir):
    try:
        Image.open(img_dir + file)
    except:
        os.remove(img_dir + file)
        print(file)
        count += 1
print(count)
# Out:
# 0

# %%
img = Image.open('data/liver_MRI/1770160.jpg')
plt.imshow(img)
# 查看像素大小
print(img.size)
# Out:
# (350, 288)

# %%
train = pd.read_csv("data/survival_train.csv")
test = pd.read_csv("data/survival_test.csv")
data = pd.concat([train, test])

# %%
data.event.mean()
# Out:
# 0.07875955786063137

# %%
import networks
d = networks.SurvivalDataset("data/survial.csv", "data/liver_MRI/")

# %%
d[0][0].shape
# Out:
# torch.Size([1, 224, 224])

# %%
#data.loc[data['eid'] in os.listdir(img_dir)]
data.loc[data['eid'].isin([int(file.split(".")[0]) for file in os.listdir(img_dir)])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #data.loc[data['eid'] in os.listdir(img_dir)]
# ----> 2 data.loc[data['eid'].isin([int(file.split(".")[0]) for file in os.listdir(img_dir)])]
#
# NameError: name 'data' is not defined

# %%
tem = data.iloc[:100]
tem.iloc[:, 1:54] = (tem.iloc[:, 1:54] - tem.iloc[:, 1:54].min(axis=0)) / (
            tem.iloc[:, 1:54].max(axis=0) - tem.iloc[:, 1:54].min(axis=0)
        )
# Out:
# C:\Users\wang\AppData\Local\Temp\ipykernel_15020\3840147217.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tem.iloc[:, 1:54] = (tem.iloc[:, 1:54] - tem.iloc[:, 1:54].min(axis=0)) / (
# C:\Users\wang\AppData\Local\Temp\ipykernel_15020\3840147217.py:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   tem.iloc[:, 1:54] = (tem.iloc[:, 1:54] - tem.iloc[:, 1:54].min(axis=0)) / (
